# %% [markdown]
# ### DPCN Team Baby Sharks Project
# - Amey Choudhary
# - Aryan Gupta
# - Keshav Gupta

# %%
# Modular code from here

# Flow of the pipeline
# 1. Read the data
# 2. Perform Signal Decomposition
# 3. Train the models
# 4. Forecast the results

# %% [markdown]
# # STL

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch.nn as  nn
import torch.optim as optim
import torch

# %%
# Selecting the dataset. Change the file path and type of data. manual
file_path ="./Datasets/Malaria_datasets/Venezuela_Malaria.xlsx"

# Reading the data
dataset = pd.read_excel(file_path)

print("The shape of the dataset: ", dataset.shape)
print("The first 5 entries are:" )
print(dataset.head())
# Out:
# The shape of the dataset:  (669, 2)
# The first 5 entries are:
#    Weeks  Cases
# 0      1    588
# 1      2    635
# 2      3    405
# 3      4    425
# 4      5    452

# %%
location = file_path.split("/")[-1].split("_")[0]
disease = file_path.split("/")[-1].split("_")[1].split(".")[0]

# selecting the hyperparameters for the dataset from excel
hyperparameters = pd.read_excel("./Suggested hyper-parameter values of EWNet model.xlsx")

# finding the hyperparameters for the dataset
for i in range(hyperparameters.shape[0]):
    name = hyperparameters.iloc[i, 0]
    loc = name.split(" ")[0]
    dis = name.split(" ")[1]
    if loc == location and dis == disease:
        hyperparameters_index = i
        break

# type of dataset as in weekly or monthly. need to set this manual after looking at the dataset values
type_of_dataset = "Weekly" # "Weekly" or "Monthly

# select the index of time, manual
index_of_cases = 1

# select the forecast type manual
forecast_type = "Medium" # "Short" or "Medium" or "Long"

p = hyperparameters[forecast_type][hyperparameters_index]
k = (p+1)//2

pred_length_weekly = {"Short": 13, "Medium": 26, "Long": 52}
pred_length_monthly = {"Short": 3, "Medium": 6, "Long": 12}

if type_of_dataset == "Weekly":
    pred_length = pred_length_weekly[forecast_type]
else:
    pred_length = pred_length_monthly[forecast_type]

test_size = pred_length
valid_size = 2*pred_length
train_size = dataset.shape[0] - test_size - valid_size-p # p is the lag, so train size wont contain the first p values


print("The value of p:",p)
print("The value of k:", k)
print("The prediction length is:", pred_length)
# Out:
# The value of p: 12
# The value of k: 6
# The prediction length is: 26

# %%
# changing to time series data
cases_time_series = dataset.iloc[:, index_of_cases].values
plt.plot(cases_time_series)
plt.title("Time series data of the cases")
plt.show()

# %%
cases_time_series_pruned = cases_time_series[0:train_size+valid_size+p]

# scaling the data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(-1, 1))
cases_time_series_scaled = scaler.fit_transform(cases_time_series_pruned.reshape(-1, 1)).reshape(-1)

# %%
from statsmodels.tsa.seasonal import STL

# convert the time series data to pandas dataframe
cases_time_series_scaled = pd.Series(cases_time_series_scaled)
stl = STL(cases_time_series_scaled, period=52)
res = stl.fit()

seasonal, trend, resid = res.seasonal, res.trend, res.resid
res.plot()
plt.show()

# %%
IMFs = []
IMFs.append(resid.tolist())
IMFs.append(trend.tolist())
IMFs.append(seasonal.tolist())
IMFs = np.array(IMFs)

n_imfs = len(IMFs)

# %%
# plotting the IMFs
plt.figure(figsize=(30, 15))
for i in range(n_imfs):
    plt.subplot(n_imfs, 1, i+1)
    plt.plot(IMFs[i, :])
    plt.title("IMF "+str(i+1))
plt.show()

# %%
# checking the IMFs and actual
reconstructed_time_series = IMFs.sum(axis=0)
plt.figure(figsize=(20, 10))
plt.plot(cases_time_series_scaled, label="Original" )
plt.plot(reconstructed_time_series, label="Reconstructed", linestyle="--")
plt.title("Original vs Reconstructed")
plt.legend()
plt.show()

# %% [markdown]
# clearly the decomposition is done well

# %%
# creating the class for neural network
class EWNet(nn.Module):
    def __init__(self, p, k):
        super(EWNet, self).__init__()
        self.fc1 = nn.Linear(p, k)
        self.fc2 = nn.Linear(k, 1)
        self.act = nn.Sigmoid()

    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        x = self.fc2(x)
        return x

# %%
# creating the train dataset and test dataset

# Define function to create lagged sequences
def create_lagged_sequence(data, lag):
    X, y = [], []
    for i in range(len(data)-lag):
        X.append(data[i:(i+lag)])
        y.append(data[i+lag])
    return np.array(X), np.array(y)



X_train = []
y_train = []
X_valid = []
y_valid = []

for i in range(n_imfs):
    X, y = create_lagged_sequence(IMFs[i], p)
    X = torch.tensor(X, dtype=torch.float32)
    y = torch.tensor(y, dtype=torch.float32)
    X_train.append(X[0:train_size])
    y_train.append(y[0:train_size])
    X_valid.append(X[train_size:train_size+valid_size])
    y_valid.append(y[train_size:train_size+valid_size])

# %%
print("The shape of X_train[0]:", X_train[0].shape)
print("The shape of y_train[0]:", y_train[0].shape)
print("The shape of X_valid[0]:", X_valid[0].shape)
print("The shape of y_valid[0]:", y_valid[0].shape)
# Out:
# The shape of X_train[0]: torch.Size([579, 12])
# The shape of y_train[0]: torch.Size([579])
# The shape of X_valid[0]: torch.Size([52, 12])
# The shape of y_valid[0]: torch.Size([52])

# %%
# running the model
n_models = []

fig, axes = plt.subplots(n_imfs, 3, figsize=(15, 5*n_imfs))

for i in range(n_imfs):

    # initializing the model
    model = EWNet(p, k)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    epochs = 10000
    print_freq = 10
    epoch_freq = epochs//print_freq
    train_losses = []
    valid_losses = []

    print("Training started for model: ", i+1)
    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        y_train_pred = model(X_train[i])
        y_train_pred = y_train_pred.view(-1)
        loss = criterion(y_train_pred, y_train[i])
        loss.backward()
        optimizer.step()
        train_losses.append(loss.item())
        with torch.no_grad():
            model.eval()
            y_valid_pred = model(X_valid[i])
            y_valid_pred = y_valid_pred.view(-1)
            valid_loss = criterion(y_valid_pred, y_valid[i])
            valid_losses.append(valid_loss.item())
        if epoch % epoch_freq == 0:
            print("Epoch: ", epoch, "Training Loss: ", loss.item(), "Validation Loss: ", valid_loss.item())
    print("Training completed for model: ", i+1)

    # Saving the model
    n_models.append(model)

    # Plot training and validation losses
    axes[i, 0].plot(train_losses, label="Train Loss")
    axes[i, 0].plot(valid_losses, label="Valid Loss")
    axes[i, 0].set_title("Losses for IMF "+str(i+1))
    axes[i, 0].legend()

    # Plotting the predicted vs actual for training
    axes[i, 1].plot(y_train[i], label="Actual")
    axes[i, 1].plot(y_train_pred.detach().numpy(), label="Predicted", linestyle="--")
    axes[i, 1].set_title("Training Predicted vs Actual for IMF "+str(i+1) + " after complete training" , fontsize=10)
    axes[i, 1].legend()

    # Plotting the predicted vs actual for validation
    axes[i, 2].plot(y_valid[i], label="Actual")
    axes[i, 2].plot(y_valid_pred.detach().numpy(), label="Predicted", linestyle="--")
    axes[i, 2].set_title("Validation Predicted vs Actual for IMF "+str(i+1) + " after complete training", fontsize=10)
    axes[i, 2].legend()

plt.tight_layout()
plt.show()
# Out:
# Training started for model:  1
# Epoch:  0 Training Loss:  0.04629101976752281 Validation Loss:  0.028305448591709137
# Epoch:  1000 Training Loss:  0.013427813537418842 Validation Loss:  0.006071894429624081
# Epoch:  2000 Training Loss:  0.012963599525392056 Validation Loss:  0.006354053504765034
# Epoch:  3000 Training Loss:  0.012926041148602962 Validation Loss:  0.006388570182025433
# Epoch:  4000 Training Loss:  0.012747282162308693 Validation Loss:  0.006749316584318876
# Epoch:  5000 Training Loss:  0.012334177270531654 Validation Loss:  0.007890557870268822
# Epoch:  6000 Training Loss:  0.012028689496219158 Validation Loss:  0.008544945158064365
# Epoch:  7000 Training Loss:  0.01159602403640747 Validation Loss:  0.008672831580042839
# Epoch:  8000 Training Loss:  0.010811040177941322 Validation Loss:  0.010711193084716797
# Epoch:  9000 Training Loss:  0.01037956029176712 Validation Loss:  0.012521945871412754
# Training completed for model:  1
# Training started for model:  2
# Epoch:  0 Training Loss:  1.2791239023208618 Validation Loss:  0.32247278094291687
# Epoch:  1000 Training Loss:  0.008418001234531403 Validation Loss:  0.03110980987548828
# Epoch:  2000 Training Loss:  0.0035402984358370304 Validation Loss:  0.0010061534121632576
# Epoch:  3000 Training Loss:  0.0010540892835706472 Validation Loss:  0.010799041949212551
# Epoch:  4000 Training Loss:  0.0006040757289156318 Validation Loss:  0.01370303425937891
# Epoch:  5000 Training Loss:  0.00037208592402748764 Validation Loss:  0.007333151996135712
# Epoch:  6000 Training Loss:  0.00016551237786188722 Validation Loss:  0.002873323392122984
# Epoch:  7000 Training Loss:  4.8776022595120594e-05 Validation Loss:  0.0006744629936292768
# Epoch:  8000 Training Loss:  2.2297748728306033e-05 Validation Loss:  7.879293116275221e-05
# Epoch:  9000 Training Loss:  1.917539157147985e-05 Validation Loss:  1.6116278857225552e-05
# Training completed for model:  2
# Training started for model:  3
# Epoch:  0 Training Loss:  0.02090390771627426 Validation Loss:  0.03775700554251671
# Epoch:  1000 Training Loss:  0.008639800362288952 Validation Loss:  0.017777564004063606
# Epoch:  2000 Training Loss:  0.008225812576711178 Validation Loss:  0.016601281240582466
# Epoch:  3000 Training Loss:  0.007933691143989563 Validation Loss:  0.016267996281385422
# Epoch:  4000 Training Loss:  0.007163172122091055 Validation Loss:  0.018322492018342018
# Epoch:  5000 Training Loss:  0.005743188783526421 Validation Loss:  0.02645968273282051
# Epoch:  6000 Training Loss:  0.005071928724646568 Validation Loss:  0.029637565836310387
# Epoch:  7000 Training Loss:  0.004677739925682545 Validation Loss:  0.027407553046941757
# Epoch:  8000 Training Loss:  0.004072003997862339 Validation Loss:  0.024246279150247574
# Epoch:  9000 Training Loss:  0.0037784650921821594 Validation Loss:  0.02359890192747116
# Training completed for model:  3

# %%
# testing the models
y_test_pred_final = []

for i in range(n_imfs):
    initial_input = IMFs[i][ -p:]
    y_test_pred_imfs = []
    
    model = n_models[i]
    model.eval()    
    
    with torch.no_grad():
        for j in range(test_size):
            y_pred = model(torch.tensor(initial_input[-p:], dtype=torch.float32))
            y_test_pred_imfs.append(y_pred.item())
            initial_input = np.append(initial_input, y_pred.item())
    

    y_test_pred_final.append(y_test_pred_imfs)

# %%
y_test_pred_final = np.array(y_test_pred_final)
y_test_pred_final = y_test_pred_final.sum(axis=0)
y_test_pred_final = scaler.inverse_transform(y_test_pred_final.reshape(-1, 1)).reshape(-1)

# %%
# calculating RMSE loss and  comparing the results
y_test_pred = np.array(y_test_pred_final)
y_test_true = np.array(cases_time_series[-test_size:])
# print("The RMSE loss is: ", np.sqrt(np.mean((y_test_pred - y_test_true)**2)))

rmse = np.sqrt(np.mean((y_test_pred - y_test_true)**2))
mae = np.mean(np.abs(y_test_pred - y_test_true))
mase = np.mean(np.abs(y_test_pred - y_test_true))/np.mean(np.abs(y_test_true[1:] - y_test_true[:-1]))
smape = 100*np.mean(2*np.abs(y_test_pred - y_test_true)/(np.abs(y_test_pred) + np.abs(y_test_true)))

# tabulate the results
results = pd.DataFrame({"RMSE": [rmse], "MAE": [mae], "MASE": [mase], "sMAPE": [smape]})
print("The results are:")
print(results)


plt.plot(y_test_true, label="Actual", linestyle= "dotted")
plt.plot(y_test_pred, label="Predicted", linestyle="--")
plt.title("Actual vs Predicted for test data for STL and forecast horizon of "+forecast_type)
plt.legend()
plt.show()
# Out:
# The results are:
#          RMSE         MAE      MASE      sMAPE
# 0  375.267688  345.625339  2.031179  23.654446

# %%
file_path = "./Datasets/Malaria_datasets/Venezuela_Malaria.xlsx"
location = file_path.split("/")[-1].split("_")[0]
disease = file_path.split("/")[-1].split("_")[1].split(".")[0]
type_of_dataset = "Weekly"
index_of_cases = 1


for i in range(hyperparameters.shape[0]):
    name = hyperparameters.iloc[i, 0]
    loc = name.split(" ")[0]
    dis = name.split(" ")[1]
    if loc == location and dis == disease:
        hyperparameters_index = i
        break

    

for time in ["Short", "Medium", "Long"]:
    p = hyperparameters[time][hyperparameters_index]
    k = (p+1)//2
    pred_length_weekly = {"Short": 13, "Medium": 26, "Long": 52}
    pred_length_monthly = {"Short": 3, "Medium": 6, "Long": 12}
    if type_of_dataset == "Weekly":
        pred_length = pred_length_weekly[time]
    else:
        pred_length = pred_length_monthly[time]
    test_size = pred_length
    valid_size = 2*pred_length
    train_size = dataset.shape[0] - test_size - valid_size-p
    cases_time_series = dataset.iloc[:, index_of_cases].values
    cases_time_series_pruned = cases_time_series[0:train_size+valid_size+p]
    scaler = MinMaxScaler(feature_range=(-1, 1))
    cases_time_series_scaled = scaler.fit_transform(cases_time_series_pruned.reshape(-1, 1)).reshape(-1)
    cases_time_series_scaled = pd.Series(cases_time_series_scaled)
    stl = STL(cases_time_series_scaled, period=52)
    res = stl.fit()
    seasonal, trend, resid = res.seasonal, res.trend, res.resid
    IMFs = []
    IMFs.append(resid.tolist())
    IMFs.append(trend.tolist())
    IMFs.append(seasonal.tolist())
    IMFs = np.array(IMFs)
    n_imfs = len(IMFs)
    X_train = []
    y_train = []
    X_valid = []
    y_valid = []
    for i in range(n_imfs):
        X, y = create_lagged_sequence(IMFs[i], p)
        X = torch.tensor(X, dtype=torch.float32)
        y = torch.tensor(y, dtype=torch.float32)
        X_train.append(X[0:train_size])
        y_train.append(y[0:train_size])
        X_valid.append(X[train_size:train_size+valid_size])
        y_valid.append(y[train_size:train_size+valid_size])
    n_models = []
    for i in range(n_imfs):
        model = EWNet(p, k)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        epochs = 10000
        print_freq = 10
        epoch_freq = epochs//print_freq
        train_losses = []
        valid_losses = []
        for epoch in range(epochs):
            model.train()
            optimizer.zero_grad()
            y_train_pred = model(X_train[i])
            y_train_pred = y_train_pred.view(-1)
            loss = criterion(y_train_pred, y_train[i])
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())
            with torch.no_grad():
                model.eval()
                y_valid_pred = model(X_valid[i])
                y_valid_pred = y_valid_pred.view(-1)
                valid_loss = criterion(y_valid_pred, y_valid[i])
                valid_losses.append(valid_loss.item())

        n_models.append(model)
        print("Training completed for model time: ", time, "IMF: ", i+1)
    y_test_pred_final = []
    for i in range(n_imfs):
        initial_input = IMFs[i][ -p:]
        y_test_pred_imfs = []
        model = n_models[i]
        model.eval()
        with torch.no_grad():
            for j in range(test_size):
                y_pred = model(torch.tensor(initial_input[-p:], dtype=torch.float32))
                y_test_pred_imfs.append(y_pred.item())
                initial_input = np.append(initial_input, y_pred.item())
        y_test_pred_final.append(y_test_pred_imfs)

    y_test_pred_final = np.array(y_test_pred_final)
    y_test_pred_final = y_test_pred_final.sum(axis=0)
    y_test_pred_final = scaler.inverse_transform(y_test_pred_final.reshape(-1, 1)).reshape(-1)
    y_test_pred = np.array(y_test_pred_final)
    y_test_true = np.array(cases_time_series[-test_size:])
    rmse = np.sqrt(np.mean((y_test_pred - y_test_true)**2))
    mae = np.mean(np.abs(y_test_pred - y_test_true))
    mase = np.mean(np.abs(y_test_pred - y_test_true))/np.mean(np.abs(y_test_true[1:] - y_test_true[:-1]))
    smape = 100*np.mean(2*np.abs(y_test_pred - y_test_true)/(np.abs(y_test_pred) + np.abs(y_test_true)))
    results = pd.DataFrame({"RMSE": [rmse], "MAE": [mae], "MASE": [mase], "sMAPE": [smape]})
    print("The results are for time: ", time)
    print(results)
    plt.plot(y_test_true, label="Actual", linestyle= "dotted")
    plt.plot(y_test_pred, label="Predicted", linestyle="--")
    plt.title("Actual vs Predicted for test data for STL and forecast horizon of "+time)
    plt.legend()
    plt.show()
# Out:
# Training completed for model time:  Short IMF:  1
# Training completed for model time:  Short IMF:  2
# Training completed for model time:  Short IMF:  3
# The results are for time:  Short
#          RMSE         MAE      MASE      sMAPE
# 0  361.456562  301.158092  2.298917  21.490137
# Training completed for model time:  Medium IMF:  1
# Training completed for model time:  Medium IMF:  2
# Training completed for model time:  Medium IMF:  3
# The results are for time:  Medium
#          RMSE         MAE      MASE      sMAPE
# 0  283.784716  244.954708  1.439555  16.105981
# Training completed for model time:  Long IMF:  1
# Training completed for model time:  Long IMF:  2
# Training completed for model time:  Long IMF:  3
# The results are for time:  Long
#          RMSE         MAE      MASE    sMAPE
# 0  590.428432  534.692056  3.211553  43.4116

# %%
def Perf_STL(dataset, hyperparameters, hyperparameters_index, type_of_dataset, index_of_cases):
    ressss = []
    for time in ["Short", "Medium", "Long"]:
        p = hyperparameters[time][hyperparameters_index]
        k = (p+1)//2
        pred_length_weekly = {"Short": 13, "Medium": 26, "Long": 52}
        pred_length_monthly = {"Short": 3, "Medium": 6, "Long": 12}
        if type_of_dataset == "Weekly":
            pred_length = pred_length_weekly[time]
        else:
            pred_length = pred_length_monthly[time]
        test_size = pred_length
        valid_size = 2*pred_length
        train_size = dataset.shape[0] - test_size - valid_size-p
        cases_time_series = dataset.iloc[:, index_of_cases].values
        cases_time_series_pruned = cases_time_series[0:train_size+valid_size+p]
        scaler = MinMaxScaler(feature_range=(-1, 1))
        cases_time_series_scaled = scaler.fit_transform(cases_time_series_pruned.reshape(-1, 1)).reshape(-1)
        cases_time_series_scaled = pd.Series(cases_time_series_scaled)
        stl = STL(cases_time_series_scaled, period=52)
        res = stl.fit()
        seasonal, trend, resid = res.seasonal, res.trend, res.resid
        IMFs = []
        IMFs.append(resid.tolist())
        IMFs.append(trend.tolist())
        IMFs.append(seasonal.tolist())
        IMFs = np.array(IMFs)
        n_imfs = len(IMFs)
        X_train = []
        y_train = []
        X_valid = []
        y_valid = []
        for i in range(n_imfs):
            X, y = create_lagged_sequence(IMFs[i], p)
            X = torch.tensor(X, dtype=torch.float32)
            y = torch.tensor(y, dtype=torch.float32)
            X_train.append(X[0:train_size])
            y_train.append(y[0:train_size])
            X_valid.append(X[train_size:train_size+valid_size])
            y_valid.append(y[train_size:train_size+valid_size])
        n_models = []
        for i in range(n_imfs):
            model = EWNet(p, k)
            criterion = nn.MSELoss()
            optimizer = optim.Adam(model.parameters(), lr=0.001)
            epochs = 10000
            print_freq = 10
            epoch_freq = epochs//print_freq
            train_losses = []
            valid_losses = []
            for epoch in range(epochs):
                model.train()
                optimizer.zero_grad()
                y_train_pred = model(X_train[i])
                y_train_pred = y_train_pred.view(-1)
                loss = criterion(y_train_pred, y_train[i])
                loss.backward()
                optimizer.step()
                train_losses.append(loss.item())
                with torch.no_grad():
                    model.eval()
                    y_valid_pred = model(X_valid[i])
                    y_valid_pred = y_valid_pred.view(-1)
                    valid_loss = criterion(y_valid_pred, y_valid[i])
                    valid_losses.append(valid_loss.item())

            n_models.append(model)
            # print("Training completed for model time: ", time, "IMF: ", i+1)
        y_test_pred_final = []
        for i in range(n_imfs):
            initial_input = IMFs[i][ -p:]
            y_test_pred_imfs = []
            model = n_models[i]
            model.eval()
            with torch.no_grad():
                for j in range(test_size):
                    y_pred = model(torch.tensor(initial_input[-p:], dtype=torch.float32))
                    y_test_pred_imfs.append(y_pred.item())
                    initial_input = np.append(initial_input, y_pred.item())
            y_test_pred_final.append(y_test_pred_imfs)

        y_test_pred_final = np.array(y_test_pred_final)
        y_test_pred_final = y_test_pred_final.sum(axis=0)
        y_test_pred_final = scaler.inverse_transform(y_test_pred_final.reshape(-1, 1)).reshape(-1)
        y_test_pred = np.array(y_test_pred_final)
        y_test_true = np.array(cases_time_series[-test_size:])
        rmse = np.sqrt(np.mean((y_test_pred - y_test_true)**2))
        mae = np.mean(np.abs(y_test_pred - y_test_true))
        mase = np.mean(np.abs(y_test_pred - y_test_true))/np.mean(np.abs(y_test_true[1:] - y_test_true[:-1]))
        smape = 100*np.mean(2*np.abs(y_test_pred - y_test_true)/(np.abs(y_test_pred) + np.abs(y_test_true)))
        results = []
        results.append(rmse)
        results.append(mae)
        results.append(mase)
        results.append(smape)
        results.append(time)
        ressss.append(results)
    return ressss

# %%
import os
from tabulate import tabulate

paths = []
for root, dirs, files in os.walk("./Datasets"):
    for file in files:
        if file.endswith(".xlsx"):
            paths.append(os.path.join(root, file))

results = []          

for file_path in paths:
    location = file_path.split("/")[-1].split("_")[0]
    disease = file_path.split("/")[-1].split("_")[1].split(".")[0]
    dataset = pd.read_excel(file_path)
    hyperparameters = pd.read_excel("./Suggested hyper-parameter values of EWNet model.xlsx")
    for i in range(hyperparameters.shape[0]):
        name = hyperparameters.iloc[i, 0]
        loc = name.split(" ")[0]
        dis = name.split(" ")[1]
        if loc == location and dis == disease:
            hyperparameters_index = i
            break
    type_of_dataset = hyperparameters["Type"][hyperparameters_index]
    index_of_cases =  hyperparameters["Column"][hyperparameters_index]
    re = Perf_STL(dataset, hyperparameters, hyperparameters_index, type_of_dataset, index_of_cases)
    for r in re:
        r.insert(0, location)
        r.insert(1, disease)
    results.append(re)

final_results = []
for res in results:
    for r in res:
        final_results.append(r)
final_results = pd.DataFrame(final_results, columns=["Location", "Disease", "RMSE", "MAE", "MASE", "sMAPE", "Forecast Type"])
print(tabulate(final_results, headers='keys', tablefmt='pretty'))
# Out:
# +----+-------------+-----------+--------------------+--------------------+--------------------+--------------------+---------------+
# |    |  Location   |  Disease  |        RMSE        |        MAE         |        MASE        |       sMAPE        | Forecast Type |
# +----+-------------+-----------+--------------------+--------------------+--------------------+--------------------+---------------+
# | 0  |  Colombia   |  Malaria  | 1636.1507772936586 | 1514.0067894796912 | 12.495241728855772 | 86.07158531512161  |     Short     |
# | 1  |  Colombia   |  Malaria  |  864.78326282041   | 839.3064776406839  | 7.380464981011993  | 55.51074967870725  |    Medium     |
# | 2  |  Colombia   |  Malaria  | 632.1221854712967  | 554.4045475356711  | 3.055065577992353  | 34.19710883695677  |     Long      |
# | 3  |  Venezuela  |  Malaria  | 389.33150358136766 | 344.91277796030045 | 2.6329219691625987 | 24.46201473273103  |     Short     |
# | 4  |  Venezuela  |  Malaria  | 383.49469249526993 | 287.98377148233925 | 1.6924293105450121 |  19.7332081878145  |    Medium     |
# | 5  |  Venezuela  |  Malaria  | 543.3285036704343  | 482.0407987908962  |  2.8953104155383   | 38.14644450635329  |     Long      |
# | 6  |    China    | Hepatitis | 4885.926796051434  | 3853.804068814963  | 0.5182630539019585 | 3.924352695594923  |     Short     |
# | 7  |    China    | Hepatitis | 12782.662632551883 | 11892.130129838983 | 2.516320382953657  | 12.742972445425101 |    Medium     |
# | 8  |    China    | Hepatitis | 12580.887399342695 | 10763.795815303922 | 1.7218316580868631 | 11.606995939798852 |     Long      |
# | 9  | Philippines |  Dengue   | 15.940624398079203 | 13.614920477400906 | 0.2370969006308531 | 21.10891342814514  |     Short     |
# | 10 | Philippines |  Dengue   | 98.63566556966163  | 80.42597588926154  | 3.0529903135102114 | 86.86723872175084  |    Medium     |
# | 11 | Philippines |  Dengue   | 291.99851879706233 | 259.75750867827304 | 7.4664718798337715 | 137.26649102196086 |     Long      |
# | 12 |  Columbia   |  Dengue   | 1402.1869488038521 | 1363.343564120623  | 14.968090365459721 | 82.32306045291259  |     Short     |
# | 13 |  Columbia   |  Dengue   | 943.0356281034069  | 835.5047263719428  | 8.638386335524636  | 51.83551131155896  |    Medium     |
# | 14 |  Columbia   |  Dengue   | 834.0930442187549  | 745.7239309062178  | 4.519538975189199  | 39.709179592490216 |     Long      |
# | 15 |   Sanjuan   |  Dengue   | 65.89419354313752  | 59.60096372835911  | 3.995595333744745  | 63.12704981559034  |     Short     |
# | 16 |   Sanjuan   |  Dengue   |  73.4250729272351  | 62.750275800721006 | 3.4554116630352976 | 51.020058914843915 |    Medium     |
# | 17 |   Sanjuan   |  Dengue   | 113.33125797285813 | 85.17244125992202  | 5.316761939113859  | 120.05853586667537 |     Long      |
# | 18 |  Ahmedabad  |  Dengue   | 8.265290435852062  | 6.787014306737826  | 0.9932216058640722 | 45.237852096265414 |     Short     |
# | 19 |  Ahmedabad  |  Dengue   | 17.965278649989088 | 14.92289892369165  | 1.650763155275625  | 69.62783779933753  |    Medium     |
# | 20 |  Ahmedabad  |  Dengue   | 25.96689055183188  | 21.160583618025367 | 4.072414205733184  | 115.69815954992629 |     Long      |
# | 21 |  Venezuela  |  Dengue   | 477.38822987508996 | 385.3411756868545  | 2.3520315911710346 | 29.26960939035223  |     Short     |
# | 22 |  Venezuela  |  Dengue   | 707.4783908624029  | 665.2636255691759  | 4.9147726475264175 | 53.25928207818518  |    Medium     |
# | 23 |  Venezuela  |  Dengue   | 642.6765728140194  | 527.3907246102506  | 3.3083550990310924 | 41.01231901599416  |     Long      |
# | 24 |   Iquitos   |  Dengue   | 7.690895325400056  | 6.522887184069707  | 1.262494293690911  | 124.03287999162953 |     Short     |
# | 25 |   Iquitos   |  Dengue   | 11.977884167072201 | 9.867266157498726  | 1.601828921671871  | 82.53598593736204  |    Medium     |
# | 26 |   Iquitos   |  Dengue   | 14.382554621036826 | 10.003542345303755 | 2.2981110793265387 | 172.7270719688854  |     Long      |
# | 27 |   Bangkok   |  Dengue   | 224.38413576402118 | 199.46602252125732 | 0.5548428999200482 | 18.13299545985604  |     Short     |
# | 28 |   Bangkok   |  Dengue   | 336.1029607326338  | 265.42733570436627 | 1.0279912304584287 | 24.141346949156596 |    Medium     |
# | 29 |   Bangkok   |  Dengue   | 496.0872569255011  | 416.2757653196654  | 1.8257709005248484 | 58.153571755046606 |     Long      |
# | 30 |  Singapore  |  Dengue   | 259.4057574646614  | 199.7590259038485  | 3.9296857554855444 |  57.1479959662218  |     Short     |
# | 31 |  Singapore  |  Dengue   | 232.04458078705937 | 165.55447488106213 | 4.122372382496567  | 60.81781552338622  |    Medium     |
# | 32 |  Singapore  |  Dengue   | 122.67830139634037 | 81.64171603092781  | 2.2147486795624034 | 32.593712752398346 |     Long      |
# | 33 |  HongKong   |  Dengue   | 5.051964611512634  | 4.428123575324814  | 1.7712494301299255 | 48.17413064245783  |     Short     |
# | 34 |  HongKong   |  Dengue   | 6.793529897589572  |  5.53830402965347  | 1.8461013432178233 | 49.25559446893632  |    Medium     |
# | 35 |  HongKong   |  Dengue   | 13.46353570234453  |  10.8941181798776  | 2.853221428063181  | 99.80707830137521  |     Long      |
# | 36 |   Mexico    | Influenza | 15.857373871277556 | 14.114791308458035 |  2.19970773638307  | 148.8091391040828  |     Short     |
# | 37 |   Mexico    | Influenza | 13.871496436421294 | 12.721848664375452 | 2.391324936912679  | 85.77817241444815  |    Medium     |
# | 38 |   Mexico    | Influenza |  73.8109346699503  |  52.6700778901577  | 3.474998670631362  | 197.18703508659416 |     Long      |
# | 39 |    Japan    | Influenza | 18.56641796133846  |  16.4989071901028  | 1.8332119100114221 | 102.91873095085253 |     Short     |
# | 40 |    Japan    | Influenza | 100.72777571876784 | 92.81599197020897  | 16.340843656726932 | 167.12959659012918 |    Medium     |
# | 41 |    Japan    | Influenza | 260.53418993746726 | 240.13359733728262 | 5.526540371932046  | 140.42687246303163 |     Long      |
# | 42 |  Australia  | Influenza | 53.52018530356459  |  47.3059217184782  | 2.345748184387349  | 75.69676308680359  |     Short     |
# | 43 |  Australia  | Influenza | 65.90424431455106  | 54.82540845412474  | 2.217856329050354  |  89.1431918690327  |    Medium     |
# | 44 |  Australia  | Influenza | 76.26473192108779  | 64.59547060054655  | 4.067122222997376  | 88.58841651237277  |     Long      |
# +----+-------------+-----------+--------------------+--------------------+--------------------+--------------------+---------------+

# %%
final_results.to_excel("STL.xlsx", index=False)
